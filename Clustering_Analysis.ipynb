# %%
import pandas as pd

# Load the dataset
csv_url = "https://data.ny.gov/resource/k7j9-jnct.csv"
data = pd.read_csv(csv_url)

data
# Out:
#       c_a  unit       scp line_name division                     date  \
# 0    A002  R051  02-00-00   NQR456W      BMT  2022-12-30T00:00:00.000
# 1    A002  R051  02-00-00   NQR456W      BMT  2022-12-30T00:00:00.000
# 2    A002  R051  02-00-00   NQR456W      BMT  2022-12-30T00:00:00.000
# 3    A002  R051  02-00-00   NQR456W      BMT  2022-12-30T00:00:00.000
# 4    A002  R051  02-00-00   NQR456W      BMT  2022-12-30T00:00:00.000
# ..    ...   ...       ...       ...      ...                      ...
# 995  A042  R086  01-00-03       NRW      BMT  2022-12-30T00:00:00.000
# 996  A042  R086  01-00-04       NRW      BMT  2022-12-30T00:00:00.000
# 997  A042  R086  01-00-04       NRW      BMT  2022-12-30T00:00:00.000
# 998  A042  R086  01-00-04       NRW      BMT  2022-12-30T00:00:00.000
# 999  A042  R086  01-00-04       NRW      BMT  2022-12-30T00:00:00.000
#
#          time description  entries    exits
# 0    03:00:00     REGULAR  7811029  2770909
# ...

# %%
import pandas as pd

# Load the dataset
csv_url = "https://data.ny.gov/resource/k7j9-jnct.csv"
data = pd.read_csv(csv_url)

# Convert 'time' column to datetime format to ensure correct sorting
data['time'] = pd.to_datetime(data['time'], format='%H:%M:%S').dt.time

# Sort by 'time' column in ascending order (from smallest to largest)
data = data.sort_values(by='time', ascending=True)

data
# Out:
#       c_a  unit       scp line_name division                     date  \
# 702  A033  R170  02-00-01  LNQR456W      BMT  2022-12-30T00:00:00.000
# 762  A034  R170  03-03-00  LNQR456W      BMT  2022-12-30T00:00:00.000
# 768  A034  R170  03-03-01  LNQR456W      BMT  2022-12-30T00:00:00.000
# 708  A033  R170  02-00-02  LNQR456W      BMT  2022-12-30T00:00:00.000
# 774  A034  R170  03-03-02  LNQR456W      BMT  2022-12-30T00:00:00.000
# ..    ...   ...       ...       ...      ...                      ...
# 893  A038  R085  00-03-00       NRW      BMT  2022-12-30T00:00:00.000
# 263  A011  R080  01-03-04      NQRW      BMT  2022-12-30T00:00:00.000
# 41   A002  R051  02-03-04   NQR456W      BMT  2022-12-30T00:00:00.000
# 257  A011  R080  01-03-03      NQRW      BMT  2022-12-30T00:00:00.000
# 599  A029  R082  00-00-01       NRW      BMT  2022-12-30T00:00:00.000
#
#          time description   entries     exits
# 702  00:00:00     REGULAR     21820     57218
# ...

# %%
# Loop through each column in the DataFrame and count the unique values
for column in data.columns:
    unique_count = data[column].nunique()
    print(f"There are {unique_count} unique values in the '{column}' column.")
# Out:
# There are 24 unique values in the 'c_a' column.
# There are 12 unique values in the 'unit' column.
# There are 63 unique values in the 'scp' column.
# There are 6 unique values in the 'line_name' column.
# There are 1 unique values in the 'division' column.
# There are 1 unique values in the 'date' column.
# There are 18 unique values in the 'time' column.
# There are 1 unique values in the 'description' column.
# There are 930 unique values in the 'entries' column.
# There are 937 unique values in the 'exits' column.

# %%
# Drop the 'division', 'description', and 'date' columns from the DataFrame
data = data.drop(columns=['division', 'description', 'date'])

# Display the first few rows to confirm the columns were removed
print(data.head())
# Out:
#     c_a  unit       scp line_name                time   entries     exits  \
# 0  A002  R051  02-00-00   NQR456W 1900-01-01 03:00:00 -0.063106 -0.115945
# 1  A002  R051  02-00-00   NQR456W 1900-01-01 07:00:00 -0.063106 -0.115944
# 2  A002  R051  02-00-00   NQR456W 1900-01-01 11:00:00 -0.063106 -0.115940
# 3  A002  R051  02-00-00   NQR456W 1900-01-01 15:00:00 -0.063104 -0.115939
# 4  A002  R051  02-00-00   NQR456W 1900-01-01 19:00:00 -0.063100 -0.115938
#
#    hour  cluster
# 0     3        0
# 1     7        0
# 2    11        0
# 3    15        0
# 4    19        0

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# Use the Elbow Method to determine optimal number of clusters
sse = []
k_values = range(1, 10)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data[['entries', 'exits']])
    sse.append(kmeans.inertia_)

# Plot the Elbow Curve
plt.figure(figsize=(8, 6))
plt.plot(k_values, sse, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Elbow Method for Optimal k')
plt.show()

# Choosing k based on the elbow plot (e.g., k=3 in this case)
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
data['cluster'] = kmeans.fit_predict(data[['entries', 'exits']])

# Displaying the cluster results
print(data[['unit', 'entries', 'exits', 'cluster']])

# Plotting clusters for visualization
plt.figure(figsize=(8, 6))
for cluster in range(optimal_k):
    cluster_data = data[data['cluster'] == cluster]
    plt.scatter(cluster_data['entries'], cluster_data['exits'], label=f'Cluster {cluster}')
plt.xlabel('Entries')
plt.ylabel('Exits')
plt.title('Cluster Analysis of Station Activity')
plt.legend()
plt.show()
# Out:
#      unit   entries     exits  cluster
# 0    R051 -0.063106 -0.115945        0
# 1    R051 -0.063106 -0.115944        0
# 2    R051 -0.063106 -0.115940        0
# 3    R051 -0.063104 -0.115939        0
# 4    R051 -0.063100 -0.115938        0
# ..    ...       ...       ...      ...
# 995  R086 -0.096932 -0.009190        0
# 996  R086 -0.174877 -0.178290        0
# 997  R086 -0.174877 -0.178289        0
# 998  R086 -0.174877 -0.178281        0
# 999  R086 -0.174875 -0.178263        0
#
# [1000 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
# Encode the 'unit' (station) column as a numerical value
le = LabelEncoder()
data['unit_encoded'] = le.fit_transform(data['unit'])

# Clustering with KMeans
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
data['cluster'] = kmeans.fit_predict(data[['unit_encoded', 'hour', 'entries', 'exits']])

# Get unique stations
stations = data['unit'].unique()

# Set up a 2-row layout for subplots
n_rows = 2
n_cols = (len(stations) + 1) // 2  # Calculate the number of columns to fit all stations in 2 rows
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 8), sharey=True)
fig.suptitle('Cluster Analysis by Station (Time vs. Entries - Scatter Plot)')

# Flatten axes array for easier indexing
axes = axes.flatten()

for i, station in enumerate(stations):
    station_data = data[data['unit'] == station]
    for cluster in station_data['cluster'].unique():
        cluster_data = station_data[station_data['cluster'] == cluster]
        axes[i].scatter(cluster_data['hour'], cluster_data['entries'], label=f'Cluster {cluster}', s=100, alpha=0.7)
    axes[i].set_title(f'Station {station}')
    axes[i].set_xlabel('Hour')
    axes[i].set_ylabel('Entries')
    axes[i].legend()

# Hide any extra subplots if the number of stations is not even
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
